# %%
# Jovian Commit Essentials
# Please retain and execute this cell without modifying the contents for `jovian.commit` to work
# !pip install jovian --upgrade -q
import jovian
jovian.set_project('cifar100-pytorch-classification')
jovian.set_colab_id('1G8HnOZcEp53BP-kY15_iVMP2g2HkgJXI')
# Out:
#      |████████████████████████████████| 71kB 4.7MB/s
#   Building wheel for uuid (setup.py) ... done

# %%
import torch
import torchvision 
from torchvision.datasets import CIFAR100

# %%
import os
from torchvision import transforms

# %%
train_set = CIFAR100(root='data/',download=True,
                    transform=transforms.Compose([
                        transforms.ToTensor(),
                    ]))
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to data/cifar-100-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=169001437.0), HTML(value='')))
# Extracting data/cifar-100-python.tar.gz to data/

# %%
len(train_set)
# Out:
# 50000

# %%
test_set = CIFAR100(root='data/',download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                   ]),train=False)
# Out:
# Files already downloaded and verified

# %%
len(test_set)
# Out:
# 10000

# %%
train_set[0]
# Out:
# (tensor([[[1.0000, 1.0000, 1.0000,  ..., 0.7647, 0.8314, 0.7137],
#           [1.0000, 0.9961, 0.9961,  ..., 0.6667, 0.6314, 0.5725],
#           [1.0000, 0.9961, 1.0000,  ..., 0.7412, 0.6510, 0.4745],
#           ...,
#           [0.5804, 0.5569, 0.5490,  ..., 0.1176, 0.2549, 0.2980],
#           [0.4784, 0.4706, 0.4941,  ..., 0.0863, 0.3804, 0.5529],
#           [0.3412, 0.3451, 0.3961,  ..., 0.1333, 0.4118, 0.5412]],
#
#          [[1.0000, 1.0000, 1.0000,  ..., 0.8039, 0.8784, 0.7608],
#           [1.0000, 0.9961, 0.9961,  ..., 0.6902, 0.6588, 0.6039],
#           [1.0000, 0.9961, 1.0000,  ..., 0.7804, 0.6980, 0.5216],
#           ...,
#           [0.7255, 0.7137, 0.7020,  ..., 0.0667, 0.2431, 0.3020],
#           [0.6157, 0.6078, 0.6275,  ..., 0.0627, 0.4392, 0.6314],
#           [0.4784, 0.4784, 0.5255,  ..., 0.1412, 0.5216, 0.6784]],
#
#          [[1.0000, 1.0000, 1.0000,  ..., 0.7569, 0.8000, 0.6549],
#           [1.0000, 0.9961, 0.9961,  ..., 0.5882, 0.5098, 0.4431],
#           [1.0000, 0.9961, 1.0000,  ..., 0.6627, 0.5098, 0.3412],
#           ...,
#           [0.3098, 0.2235, 0.2353,  ..., 0.0039, 0.0588, 0.0784],
#           [0.2588, 0.2275, 0.2784,  ..., 0.0118, 0.2196, 0.3412],
#           [0.1608, 0.1529, 0.2196,  ..., 0.0392, 0.2314, 0.3098]]]), 19)

# %%
import matplotlib.pyplot as plt

# %%
img,label = train_set[10]

# %%
img.shape
# Out:
# torch.Size([3, 32, 32])

# %%
train_set.classes
# Out:
# ['apple',
#  'aquarium_fish',
#  'baby',
#  'bear',
#  'beaver',
#  'bed',
#  'bee',
#  'beetle',
#  'bicycle',
#  'bottle',
#  'bowl',
#  'boy',
#  'bridge',
#  'bus',
#  'butterfly',
#  'camel',
#  'can',
#  'castle',
#  'caterpillar',
#  'cattle',
#  'chair',
#  'chimpanzee',
#  'clock',
#  'cloud',
#  'cockroach',
#  'couch',
#  'crab',
#  'crocodile',
#  'cup',
#  'dinosaur',
#  'dolphin',
#  'elephant',
#  'flatfish',
#  'forest',
#  'fox',
#  'girl',
#  'hamster',
#  'house',
#  'kangaroo',
#  'keyboard',
#  'lamp',
#  'lawn_mower',
#  'leopard',
#  'lion',
#  'lizard',
#  'lobster',
#  'man',
#  'maple_tree',
#  'motorcycle',
#  'mountain',
#  'mouse',
#  'mushroom',
#  'oak_tree',
#  'orange',
#  'orchid',
#  'otter',
#  'palm_tree',
#  'pear',
#  'pickup_truck',
#  'pine_tree',
#  'plain',
#  'plate',
#  'poppy',
#  'porcupine',
#  'possum',
#  'rabbit',
#  'raccoon',
#  'ray',
#  'road',
#  'rocket',
#  'rose',
#  'sea',
#  'seal',
#  'shark',
#  'shrew',
#  'skunk',
#  'skyscraper',
#  'snail',
#  'snake',
#  'spider',
#  'squirrel',
#  'streetcar',
#  'sunflower',
#  'sweet_pepper',
#  'table',
#  'tank',
#  'telephone',
#  'television',
#  'tiger',
#  'tractor',
#  'train',
#  'trout',
#  'tulip',
#  'turtle',
#  'wardrobe',
#  'whale',
#  'willow_tree',
#  'wolf',
#  'woman',
#  'worm']

# %%
print(len(train_set.classes))
# Out:
# 100

# %% [markdown]
# # Training and Validation Data

# %%
from torch.utils.data import random_split

# %%
train_ds, valid_ds = random_split(train_set,[40000, 10000])
print(len(train_ds))
print(len(valid_ds))
# Out:
# 40000
# 10000

# %% [markdown]
# # Create Dataloaders

# %%
from torch.utils.data import DataLoader

# %%
batch_size = 128

train_dl = DataLoader(train_ds,batch_size,shuffle=True)
valid_dl = DataLoader(valid_ds,batch_size)

# %% [markdown]
# # Model

# %%
import torch.nn as nn

# %%
input_shape = 32*32*3
num_classes = 100

# logistic Regression model
model = nn.Linear(input_shape,num_classes)

# %%
model.weight
# Out:
# Parameter containing:
# tensor([[ 0.0154,  0.0120, -0.0064,  ...,  0.0101,  0.0029,  0.0031],
#         [-0.0076, -0.0063,  0.0067,  ..., -0.0158, -0.0032,  0.0125],
#         [-0.0153, -0.0091,  0.0082,  ..., -0.0119, -0.0139,  0.0044],
#         ...,
#         [ 0.0005, -0.0114,  0.0017,  ...,  0.0046,  0.0053, -0.0024],
#         [-0.0075, -0.0035,  0.0143,  ..., -0.0170, -0.0019, -0.0135],
#         [ 0.0112,  0.0131, -0.0153,  ...,  0.0155,  0.0091,  0.0154]],
#        requires_grad=True)

# %%
model.bias
# Out:
# Parameter containing:
# tensor([ 0.0170, -0.0095,  0.0121, -0.0088, -0.0016, -0.0011, -0.0155, -0.0145,
#          0.0169, -0.0146, -0.0116,  0.0065,  0.0140,  0.0173, -0.0122,  0.0132,
#         -0.0012, -0.0102, -0.0106,  0.0005,  0.0045,  0.0020,  0.0059, -0.0046,
#         -0.0157, -0.0013, -0.0033,  0.0145, -0.0166, -0.0029,  0.0150, -0.0161,
#          0.0073,  0.0048,  0.0141, -0.0101,  0.0153,  0.0088,  0.0044,  0.0027,
#          0.0061,  0.0072, -0.0155,  0.0034,  0.0173,  0.0037, -0.0077,  0.0138,
#          0.0119,  0.0069, -0.0112,  0.0173, -0.0154, -0.0139, -0.0011,  0.0139,
#         -0.0132, -0.0076,  0.0174,  0.0170,  0.0169,  0.0081,  0.0050,  0.0162,
#          0.0013, -0.0167,  0.0165, -0.0043,  0.0012,  0.0012, -0.0180,  0.0161,
#          0.0084,  0.0049, -0.0066,  0.0096, -0.0034,  0.0046, -0.0074, -0.0004,
#          0.0010,  0.0084, -0.0019,  0.0132, -0.0137, -0.0049,  0.0176, -0.0024,
#          0.0065, -0.0042, -0.0003, -0.0105, -0.0036,  0.0170, -0.0013, -0.0044,
#         -0.0121, -0.0042, -0.0048, -0.0093], requires_grad=True)

# %%
for image,label in train_dl:
    print(image.shape)
    print(label)
    break
# Out:
# torch.Size([128, 3, 32, 32])
# tensor([92, 63,  1, 74, 50, 66,  7, 21, 50, 22, 97, 46, 31, 82, 20, 57, 79, 22,
#         92, 17, 80, 85, 69, 88, 63, 94, 42, 15, 73, 38,  6, 19, 76, 54, 34,  5,
#         66, 54, 85, 44, 19, 37, 42, 49, 96, 29, 66, 27,  7, 53, 36, 31, 82, 50,
#         40, 75,  7, 92, 54,  0, 55, 54, 71, 91, 11, 61,  4, 26, 87, 81, 10, 37,
#         68, 72, 99, 10, 62, 55, 78, 92, 34, 22, 17, 63,  7, 19, 70,  3,  9,  5,
#         85, 93, 49, 51, 96, 49,  6, 33, 32, 46, 74, 26, 38, 56, 49, 17, 96,  0,
#         57, 84, 98, 14, 96, 83, 19, 69, 95,  6, 56, 96, 70, 56, 99, 69, 15,  2,
#         50, 86])

# %%
image.shape
# Out:
# torch.Size([128, 3, 32, 32])

# %%
image.reshape(128,3072).shape
# Out:
# torch.Size([128, 3072])

# %%
# for images,labels in train_dl:
#     print(images.shape)
#     print(labels)
#     output = model(images)
#     print(output)

# %%
image.reshape(-1,3072).shape
# Out:
# torch.Size([128, 3072])

# %%
class Cifar100(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(input_shape,num_classes)
        
    def forward(self,xb):
        xb = xb.reshape(-1,3072)
        out = self.linear(xb)
        return out

# %%
model = Cifar100()

model(image)
# Out:
# tensor([[ 0.5831, -0.2294, -0.3432,  ..., -0.1084, -0.8165, -0.1506],
#         [ 0.3481, -0.1676, -0.1224,  ..., -0.1673, -0.5735, -0.1207],
#         [ 0.7210, -0.4380, -0.3014,  ..., -0.2174, -0.7100, -0.2460],
#         ...,
#         [ 0.6028, -0.2483, -0.1051,  ..., -0.3793, -0.9040, -0.1488],
#         [ 0.2468, -0.2892, -0.3021,  ...,  0.0831, -0.4502, -0.2019],
#         [ 0.4903, -0.3310, -0.3043,  ..., -0.3411, -0.9252, -0.0725]],
#        grad_fn=<AddmmBackward>)

# %%
model.linear
# Out:
# Linear(in_features=3072, out_features=100, bias=True)

# %%
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[ 0.0133,  0.0178, -0.0121,  ..., -0.0113, -0.0025,  0.0155],
#          [-0.0111, -0.0123, -0.0170,  ...,  0.0045, -0.0107,  0.0146],
#          [-0.0128,  0.0155, -0.0147,  ..., -0.0117, -0.0036,  0.0089],
#          ...,
#          [ 0.0123, -0.0114, -0.0064,  ...,  0.0056,  0.0063, -0.0133],
#          [ 0.0142, -0.0169,  0.0059,  ...,  0.0028, -0.0094, -0.0072],
#          [ 0.0143,  0.0131, -0.0160,  ..., -0.0161,  0.0114, -0.0068]],
#         requires_grad=True), Parameter containing:
#  tensor([-3.5063e-03,  5.9710e-03, -7.7133e-03, -9.5211e-03,  1.7909e-02,
#          -7.8174e-03,  6.5624e-03, -3.8494e-03,  1.7468e-02, -1.1239e-02,
#           7.7130e-03, -1.7913e-02, -1.0646e-02, -1.0714e-02,  1.1655e-02,
#           2.7837e-03,  3.9845e-03, -1.7540e-02,  1.0796e-02,  3.8906e-03,
#           1.4599e-03,  1.3066e-02, -1.6714e-02,  5.2310e-03,  7.0704e-03,
#           7.8022e-03,  1.4317e-02,  9.7399e-03, -1.7909e-02, -1.2635e-02,
#           1.1536e-03, -8.1165e-03,  8.8871e-03, -6.0660e-03,  8.5327e-03,
#          -1.2513e-02, -4.6482e-03,  4.9670e-04, -5.2858e-03,  1.7643e-02,
#           1.0280e-02, -8.0645e-03, -4.1684e-03, -9.2141e-03,  2.0840e-03,
#           1.5322e-02,  1.6524e-02, -8.1554e-03, -9.1869e-03, -1.7759e-02,
#           1.2502e-02,  2.9757e-03,  3.0537e-05, -4.8116e-03, -8.8097e-03,
#          -1.4834e-02,  4.7489e-03,  8.7811e-03, -1.5725e-02,  1.0444e-02,
#           1.0930e-02,  4.1706e-03,  1.5616e-02,  8.1120e-03, -2.9421e-03,
#           1.3303e-02, -9.2972e-03, -6.2299e-03,  9.1585e-03, -3.0575e-03,
#          -1.7006e-02, -1.5724e-02,  3.0560e-04,  1.7321e-02,  1.0731e-02,
#          -2.0954e-03, -1.7166e-02, -2.0681e-03,  4.9619e-03,  1.0346e-02,
#           1.6691e-02,  8.4178e-05,  1.6717e-02, -3.7805e-03,  9.7951e-03,
#           1.5490e-02, -1.0995e-02, -1.5302e-02,  5.8556e-03,  1.6921e-02,
#           5.2630e-04,  9.7472e-03, -6.5799e-03, -1.6520e-02, -1.4117e-02,
#          -9.9849e-03,  5.7637e-03, -1.5542e-03,  1.3050e-02, -1.5057e-02],
#         requires_grad=True)]

# %%
for images,labels in train_dl:
    print(images.shape)
    out = model(images)
    break
    
print("Output : ",out)
print("Output shape:",out.shape)
# Out:
# torch.Size([128, 3, 32, 32])
# Output :  tensor([[ 2.8800e-01, -1.3556e-01, -2.1269e-01,  ..., -1.9375e-01,
#          -7.6303e-01, -1.3025e-01],
#         [ 3.7471e-01, -2.5405e-01, -2.3620e-01,  ..., -3.3889e-01,
#          -1.0831e+00, -2.5756e-01],
#         [ 4.6444e-01, -4.5636e-01, -3.0820e-01,  ..., -1.7308e-01,
#          -1.0742e+00, -1.5151e-01],
#         ...,
#         [ 5.0947e-01, -1.4284e-01, -3.0434e-01,  ..., -2.1202e-01,
#          -1.1477e+00, -3.9279e-01],
#         [ 6.0159e-01, -3.5630e-01, -2.0248e-01,  ..., -4.0716e-01,
#          -9.7378e-01, -1.7582e-01],
#         [ 6.4704e-03, -8.3260e-04,  1.5862e-01,  ..., -1.5151e-01,
#          -7.2970e-01, -1.3328e-01]], grad_fn=<AddmmBackward>)
# Output shape: torch.Size([128, 100])

# %%
out[:2]
# Out:
# tensor([[ 2.8800e-01, -1.3556e-01, -2.1269e-01,  5.8173e-02, -1.7239e-01,
#          -1.5209e-01,  7.2417e-03,  1.5971e-01,  1.0019e-01,  1.2481e-01,
#           3.1253e-01,  6.1628e-02,  4.4246e-01,  2.8832e-01, -8.6264e-02,
#          -3.8433e-01,  5.4407e-01, -4.2062e-02,  3.9827e-01,  4.3345e-02,
#           4.2407e-01, -3.2041e-02,  7.6544e-02,  8.3153e-02, -4.5815e-01,
#           1.7480e-01,  2.6514e-01, -5.2727e-02, -8.6605e-02,  9.3460e-02,
#           4.1464e-01,  1.0031e-01,  8.6519e-02,  3.2429e-02,  4.4549e-01,
#          -1.7129e-01, -1.2476e-01,  1.8255e-01,  5.5376e-02,  4.1848e-02,
#          -4.0574e-02,  1.2299e-01, -5.1927e-01, -2.7974e-01, -1.8382e-01,
#           4.4732e-02,  4.4576e-02, -2.0449e-01,  5.4221e-02,  5.0591e-02,
#          -9.9524e-02, -3.9188e-01,  9.6854e-02,  1.2716e-02,  8.3878e-02,
#          -1.2642e-01, -8.9985e-02,  3.5720e-01, -3.7584e-01,  9.8921e-02,
#           1.3525e-01, -5.1734e-01,  1.4012e-01, -5.3851e-01, -4.6792e-01,
#          -9.4229e-02, -1.9575e-01, -2.6785e-02, -9.0790e-02, -1.3162e-01,
#           1.6677e-01,  2.4237e-01, -4.1167e-01, -1.4936e-01,  7.2940e-02,
#           3.4351e-02,  4.4822e-01, -4.8000e-01,  1.9304e-01, -2.0252e-01,
#           8.4471e-03,  3.9870e-02,  3.8528e-01, -6.9764e-02, -6.4559e-01,
#           1.5639e-01, -3.8424e-02,  2.9298e-01,  3.3776e-01,  1.0374e-01,
#           4.3994e-01,  2.2537e-01, -4.4615e-02, -2.2561e-01,  1.7545e-01,
#           6.7911e-02, -1.2446e-01, -1.9375e-01, -7.6303e-01, -1.3025e-01],
#         [ 3.7471e-01, -2.5405e-01, -2.3620e-01,  1.0736e-01, -1.1915e-01,
#          -1.8219e-01,  2.2535e-01,  4.4705e-01,  1.7011e-01,  2.5644e-01,
#           1.0840e-01,  2.3864e-01,  9.0763e-01,  3.0870e-01,  1.8250e-02,
#          -2.9312e-01,  5.6443e-01, -2.7103e-01,  5.7559e-01, -2.2613e-02,
#           3.6658e-01,  2.8092e-02, -1.1681e-01,  1.5163e-01, -2.5681e-01,
#           3.1555e-02,  5.7427e-02, -5.4321e-02,  8.0375e-02,  2.0223e-02,
#           5.0390e-01,  1.9166e-02,  1.6331e-01, -2.2914e-01,  6.9267e-01,
#          -3.9095e-02,  2.1784e-01,  2.6443e-01,  2.6112e-01,  2.2291e-01,
#          -1.6362e-01,  3.4326e-01, -5.3471e-01, -3.8807e-01, -3.0100e-01,
#           9.4741e-03,  1.0796e-01, -5.2015e-01,  9.4302e-02,  3.2680e-01,
#          -1.3864e-01, -1.2133e-01,  1.6730e-01,  4.3412e-01,  2.5681e-01,
#          -1.4094e-01, -8.8833e-03,  4.3378e-01, -1.9531e-01,  1.9061e-01,
#           2.4701e-01, -6.0726e-01,  5.7262e-02, -3.7343e-01, -6.8697e-01,
#          -2.6953e-01, -3.2883e-01, -1.2875e-01, -4.0712e-02, -2.0594e-01,
#           2.5025e-01,  3.6292e-01, -4.5125e-01,  4.2951e-02,  1.4931e-01,
#           1.5690e-01,  3.1550e-01, -4.2294e-01,  2.6308e-01, -4.7341e-01,
#           3.8552e-01,  5.2798e-02,  5.5866e-01, -8.8071e-02, -8.9115e-01,
#          -1.7560e-04, -1.0233e-01,  1.6834e-01,  3.9965e-01, -1.2282e-01,
#           9.2551e-02,  1.9298e-01, -1.8211e-01, -1.2586e-01,  1.5235e-02,
#           3.4110e-01, -2.3810e-01, -3.3889e-01, -1.0831e+00, -2.5756e-01]],
#        grad_fn=<SliceBackward>)

# %%
# Apply softmax for each row
import torch.nn.functional as F

# %%
probs = F.softmax(out,dim=1)

# %%
print("Sample probabilities : ", probs)
# Out:
# Sample probabilities :  tensor([[0.0129, 0.0085, 0.0078,  ..., 0.0080, 0.0045, 0.0085],
#         [0.0136, 0.0072, 0.0074,  ..., 0.0066, 0.0032, 0.0072],
#         [0.0150, 0.0060, 0.0069,  ..., 0.0079, 0.0032, 0.0081],
#         ...,
#         [0.0154, 0.0080, 0.0068,  ..., 0.0075, 0.0029, 0.0062],
#         [0.0168, 0.0064, 0.0075,  ..., 0.0061, 0.0035, 0.0077],
#         [0.0098, 0.0097, 0.0114,  ..., 0.0084, 0.0047, 0.0085]],
#        grad_fn=<SoftmaxBackward>)

# %%
max_p , p =  torch.max(probs,dim=1)

# %%
max_p , p
# Out:
# (tensor([0.0167, 0.0231, 0.0247, 0.0207, 0.0206, 0.0239, 0.0157, 0.0154, 0.0185,
#          0.0229, 0.0163, 0.0239, 0.0202, 0.0186, 0.0148, 0.0178, 0.0172, 0.0152,
#          0.0241, 0.0172, 0.0162, 0.0227, 0.0154, 0.0167, 0.0216, 0.0219, 0.0210,
#          0.0281, 0.0188, 0.0157, 0.0213, 0.0198, 0.0235, 0.0193, 0.0202, 0.0208,
#          0.0245, 0.0262, 0.0201, 0.0231, 0.0164, 0.0252, 0.0161, 0.0201, 0.0236,
#          0.0298, 0.0246, 0.0217, 0.0203, 0.0341, 0.0162, 0.0166, 0.0217, 0.0197,
#          0.0213, 0.0240, 0.0253, 0.0191, 0.0228, 0.0134, 0.0161, 0.0156, 0.0299,
#          0.0230, 0.0225, 0.0149, 0.0253, 0.0228, 0.0183, 0.0173, 0.0243, 0.0177,
#          0.0200, 0.0365, 0.0212, 0.0141, 0.0200, 0.0216, 0.0240, 0.0232, 0.0342,
#          0.0167, 0.0144, 0.0154, 0.0157, 0.0183, 0.0175, 0.0205, 0.0309, 0.0164,
#          0.0307, 0.0199, 0.0153, 0.0166, 0.0159, 0.0176, 0.0121, 0.0215, 0.0135,
#          0.0150, 0.0210, 0.0192, 0.0239, 0.0337, 0.0191, 0.0247, 0.0182, 0.0310,
#          0.0217, 0.0368, 0.0166, 0.0199, 0.0160, 0.0213, 0.0137, 0.0169, 0.0199,
#          0.0327, 0.0196, 0.0250, 0.0188, 0.0314, 0.0217, 0.0188, 0.0265, 0.0208,
#          0.0287, 0.0144], grad_fn=<MaxBackward0>),
#  tensor([16, 12, 12, 12, 12, 12, 12, 81, 12, 12, 12, 12, 12, 12, 16, 12, 12, 30,
#          12, 12, 82, 12, 20, 70, 12,  0, 12, 12, 12, 30, 12, 12, 12, 12, 12, 18,
#          12, 12, 12, 12, 34,  0, 12, 12, 12, 12, 12, 12, 16, 12, 12, 16, 12, 12,
#          12, 12, 12,  0, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 30,
#          12, 12, 12, 30, 16, 12, 12, 12, 12, 18, 38, 49,  0, 12, 12, 12, 12, 12,
#          12, 12, 49, 34, 16, 12, 20, 12, 12, 16, 12, 12, 12, 12, 12, 12, 12, 12,
#          12, 12, 12, 12, 12, 12, 62,  0,  0, 12, 16, 12, 34, 12, 12, 12, 12, 18,
#          12, 16]))

# %% [markdown]
# # Evaluation Metric and Loss Function

# %%
def accuracy(outputs,labels):
    _ , p = torch.max(outputs,dim=1)
    return torch.tensor( torch.sum(p == labels) / p.numel())

# %%
accuracy(out,labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   This is separate from the ipykernel package so we can avoid doing imports until
# tensor(0.0078)

# %%
import torch.nn.functional as F

# %%
loss_fn = F.cross_entropy

# %%
loss_fn(out,labels)
# Out:
# tensor(4.6128, grad_fn=<NllLossBackward>)

# %% [markdown]
# # Model

# %%
class Cifar100(nn.Module):
    
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(input_shape,num_classes)
        
    def forward(self,xb):
        xb = xb.reshape(-1,3072)
        yb = self.linear(xb)
        return yb
    
    def training_step(self, batch):
        images, labels = batch
        out = self(images)
        loss = F.cross_entropy(out,labels)
        acc = accuracy(out,labels)
        res = {'train_loss':loss, 'train_acc':acc}
        return loss,res
    
    def validation_step(self, batch):
        images, labels = batch
        out = self(images)
        loss = F.cross_entropy(out,labels)
        acc = accuracy(out,labels)
        return {'val_loss':loss, 'val_acc':acc}
    
    def epoch_end_compute(self, val_outputs, train_outputs):
        val_batch_losses = [x['val_loss'] for x in val_outputs]
        val_epoch_loss = torch.stack(val_batch_losses).mean()
        val_batch_acc = [x['val_acc'] for x in val_outputs]
        val_epoch_acc = torch.stack(val_batch_acc).mean()
        
        train_batch_losses = [x['train_loss'] for x in train_outputs]
        train_epoch_loss = torch.stack(train_batch_losses).mean()
        train_batch_acc = [x['train_acc'] for x in train_outputs]
        train_epoch_acc = torch.stack(train_batch_acc).mean()
        
        return {'train_loss':train_epoch_loss.item(), 'train_acc': train_epoch_acc.item(),
                'val_loss':val_epoch_loss.item(),'val_acc':val_epoch_acc.item()}
    
    def epoch_end_print(self,results,epoch,num_epochs):
        print("Epoch {}/{} : train_loss:{:.4f}, train_acc:{:.4f}, val_loss:{:.4f}, val_acc:{:.4f}".format(epoch,num_epochs,results['train_loss'],results['train_acc'],results['val_loss'],results['val_acc']))
    
model = Cifar100()

# %%
def evaluate(model, valid_dl, train_dl):
    val_outputs = [model.validation_step(batch) for batch in valid_dl]
    train_outputs = [model.training_step(batch)[1] for batch in train_dl]
    return model.epoch_end_compute(val_outputs,train_outputs)

# %%
def fit(epochs, lr, train_dl, valid_dl, opt_function = torch.optim.SGD):
    
    optimizer = opt_function(model.parameters(), lr)
    history = []
    
    for epoch in range(epochs):
        
        
        # training step
        for batch in train_dl:
            loss, train_results = model.training_step(batch)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            
        # validation step
        results = evaluate(model, valid_dl, train_dl)
        model.epoch_end_print(results, epoch, epochs)
        history.append(results)
    
    return history

# %%
evaluate(model,valid_dl, train_dl)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   This is separate from the ipykernel package so we can avoid doing imports until
# {'train_acc': 0.011157148517668247,
#  'train_loss': 4.6674041748046875,
#  'val_acc': 0.009493670426309109,
#  'val_loss': 4.670341491699219}

# %%
histroy = fit(100,0.0001,train_dl,valid_dl)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   This is separate from the ipykernel package so we can avoid doing imports until
# Epoch 0/100 : train_loss:4.6406, train_acc:0.0113, val_loss:4.6416, val_acc:0.0101
# Epoch 1/100 : train_loss:4.6227, train_acc:0.0117, val_loss:4.6223, val_acc:0.0099
# Epoch 2/100 : train_loss:4.6097, train_acc:0.0123, val_loss:4.6085, val_acc:0.0101
# Epoch 3/100 : train_loss:4.6000, train_acc:0.0136, val_loss:4.5979, val_acc:0.0134
# Epoch 4/100 : train_loss:4.5920, train_acc:0.0149, val_loss:4.5895, val_acc:0.0162
# Epoch 5/100 : train_loss:4.5853, train_acc:0.0156, val_loss:4.5825, val_acc:0.0176
# Epoch 6/100 : train_loss:4.5793, train_acc:0.0166, val_loss:4.5763, val_acc:0.0194
# Epoch 7/100 : train_loss:4.5739, train_acc:0.0178, val_loss:4.5708, val_acc:0.0204
# Epoch 8/100 : train_loss:4.5688, train_acc:0.0190, val_loss:4.5656, val_acc:0.0217
# Epoch 9/100 : train_loss:4.5639, train_acc:0.0202, val_loss:4.5607, val_acc:0.0228
# Epoch 10/100 : train_loss:4.5592, train_acc:0.0211, val_loss:4.5560, val_acc:0.0240
# Epoch 11/100 : train_loss:4.5545, train_acc:0.0227, val_loss:4.5514, val_acc:0.0257
# Epoch 12/100 : train_loss:4.5499, train_acc:0.0243, val_loss:4.5470, val_acc:0.0267
# Epoch 13/100 : train_loss:4.5455, train_acc:0.0252, val_loss:4.5426, val_acc:0.0273
# Epoch 14/100 : train_loss:4.5410, train_acc:0.0266, val_loss:4.5383, val_acc:0.0277
# Epoch 15/100 : train_loss:4.5366, train_acc:0.0279, val_loss:4.5340, val_acc:0.0290
# Epoch 16/100 : train_loss:4.5324, train_acc:0.0294, val_loss:4.5298, val_acc:0.0305
# Epoch 17/100 : train_loss:4.5280, train_acc:0.0306, val_loss:4.5257, val_acc:0.0318
# Epoch 18/100 : train_loss:4.5239, train_acc:0.0316, val_loss:4.5216, val_acc:0.0328
# Epoch 19/100 : train_loss:4.5197, train_acc:0.0329, val_loss:4.5175, val_acc:0.0344
# Epoch 20/100 : train_loss:4.5154, train_acc:0.0345, val_loss:4.5135, val_acc:0.0354
# Epoch 21/100 : train_loss:4.5114, train_acc:0.0355, val_loss:4.5095, val_acc:0.0369
# Epoch 22/100 : train_loss:4.5071, train_acc:0.0369, val_loss:4.5055, val_acc:0.0377
# Epoch 23/100 : train_loss:4.5032, train_acc:0.0384, val_loss:4.5016, val_acc:0.0383
# Epoch 24/100 : train_loss:4.4991, train_acc:0.0396, val_loss:4.4977, val_acc:0.0394
# Epoch 25/100 : train_loss:4.4952, train_acc:0.0409, val_loss:4.4939, val_acc:0.0405
# Epoch 26/100 : train_loss:4.4912, train_acc:0.0420, val_loss:4.4901, val_acc:0.0416
# Epoch 27/100 : train_loss:4.4873, train_acc:0.0433, val_loss:4.4863, val_acc:0.0423
# Epoch 28/100 : train_loss:4.4834, train_acc:0.0449, val_loss:4.4826, val_acc:0.0436
# Epoch 29/100 : train_loss:4.4796, train_acc:0.0454, val_loss:4.4789, val_acc:0.0444
# Epoch 30/100 : train_loss:4.4758, train_acc:0.0466, val_loss:4.4752, val_acc:0.0457
# Epoch 31/100 : train_loss:4.4720, train_acc:0.0477, val_loss:4.4715, val_acc:0.0468
# Epoch 32/100 : train_loss:4.4683, train_acc:0.0485, val_loss:4.4679, val_acc:0.0474
# Epoch 33/100 : train_loss:4.4645, train_acc:0.0496, val_loss:4.4643, val_acc:0.0492
# Epoch 34/100 : train_loss:4.4609, train_acc:0.0505, val_loss:4.4608, val_acc:0.0509
# Epoch 35/100 : train_loss:4.4572, train_acc:0.0517, val_loss:4.4573, val_acc:0.0519
# Epoch 36/100 : train_loss:4.4536, train_acc:0.0525, val_loss:4.4538, val_acc:0.0525
# Epoch 37/100 : train_loss:4.4499, train_acc:0.0534, val_loss:4.4504, val_acc:0.0533
# Epoch 38/100 : train_loss:4.4466, train_acc:0.0543, val_loss:4.4469, val_acc:0.0539
# Epoch 39/100 : train_loss:4.4429, train_acc:0.0553, val_loss:4.4435, val_acc:0.0549
# Epoch 40/100 : train_loss:4.4395, train_acc:0.0556, val_loss:4.4402, val_acc:0.0552
# Epoch 41/100 : train_loss:4.4359, train_acc:0.0568, val_loss:4.4369, val_acc:0.0567
# Epoch 42/100 : train_loss:4.4324, train_acc:0.0574, val_loss:4.4336, val_acc:0.0571
# Epoch 43/100 : train_loss:4.4291, train_acc:0.0582, val_loss:4.4303, val_acc:0.0578
# Epoch 44/100 : train_loss:4.4258, train_acc:0.0591, val_loss:4.4271, val_acc:0.0593
# Epoch 45/100 : train_loss:4.4224, train_acc:0.0599, val_loss:4.4238, val_acc:0.0604
# Epoch 46/100 : train_loss:4.4191, train_acc:0.0606, val_loss:4.4206, val_acc:0.0611
# Epoch 47/100 : train_loss:4.4157, train_acc:0.0613, val_loss:4.4175, val_acc:0.0618
# Epoch 48/100 : train_loss:4.4126, train_acc:0.0621, val_loss:4.4143, val_acc:0.0620
# Epoch 49/100 : train_loss:4.4093, train_acc:0.0629, val_loss:4.4112, val_acc:0.0627
# Epoch 50/100 : train_loss:4.4061, train_acc:0.0638, val_loss:4.4082, val_acc:0.0640
# Epoch 51/100 : train_loss:4.4029, train_acc:0.0643, val_loss:4.4051, val_acc:0.0644
# Epoch 52/100 : train_loss:4.3996, train_acc:0.0647, val_loss:4.4021, val_acc:0.0654
# Epoch 53/100 : train_loss:4.3965, train_acc:0.0651, val_loss:4.3991, val_acc:0.0667
# Epoch 54/100 : train_loss:4.3936, train_acc:0.0651, val_loss:4.3961, val_acc:0.0665
# Epoch 55/100 : train_loss:4.3903, train_acc:0.0661, val_loss:4.3931, val_acc:0.0670
# Epoch 56/100 : train_loss:4.3873, train_acc:0.0667, val_loss:4.3901, val_acc:0.0686
# Epoch 57/100 : train_loss:4.3843, train_acc:0.0672, val_loss:4.3873, val_acc:0.0690
# Epoch 58/100 : train_loss:4.3812, train_acc:0.0678, val_loss:4.3844, val_acc:0.0695
# Epoch 59/100 : train_loss:4.3783, train_acc:0.0683, val_loss:4.3815, val_acc:0.0707
# Epoch 60/100 : train_loss:4.3753, train_acc:0.0694, val_loss:4.3787, val_acc:0.0714
# Epoch 61/100 : train_loss:4.3725, train_acc:0.0697, val_loss:4.3759, val_acc:0.0719
# Epoch 62/100 : train_loss:4.3695, train_acc:0.0703, val_loss:4.3731, val_acc:0.0719
# Epoch 63/100 : train_loss:4.3666, train_acc:0.0709, val_loss:4.3704, val_acc:0.0726
# Epoch 64/100 : train_loss:4.3638, train_acc:0.0715, val_loss:4.3676, val_acc:0.0733
# Epoch 65/100 : train_loss:4.3610, train_acc:0.0719, val_loss:4.3649, val_acc:0.0732
# Epoch 66/100 : train_loss:4.3580, train_acc:0.0724, val_loss:4.3622, val_acc:0.0738
# Epoch 67/100 : train_loss:4.3553, train_acc:0.0727, val_loss:4.3595, val_acc:0.0744
# Epoch 68/100 : train_loss:4.3525, train_acc:0.0731, val_loss:4.3569, val_acc:0.0748
# Epoch 69/100 : train_loss:4.3498, train_acc:0.0734, val_loss:4.3543, val_acc:0.0752
# Epoch 70/100 : train_loss:4.3470, train_acc:0.0737, val_loss:4.3517, val_acc:0.0758
# Epoch 71/100 : train_loss:4.3444, train_acc:0.0742, val_loss:4.3491, val_acc:0.0765
# Epoch 72/100 : train_loss:4.3415, train_acc:0.0749, val_loss:4.3465, val_acc:0.0774
# Epoch 73/100 : train_loss:4.3390, train_acc:0.0753, val_loss:4.3439, val_acc:0.0778
# Epoch 74/100 : train_loss:4.3364, train_acc:0.0758, val_loss:4.3414, val_acc:0.0788
# Epoch 75/100 : train_loss:4.3337, train_acc:0.0764, val_loss:4.3389, val_acc:0.0790
# Epoch 76/100 : train_loss:4.3311, train_acc:0.0767, val_loss:4.3364, val_acc:0.0787
# Epoch 77/100 : train_loss:4.3285, train_acc:0.0772, val_loss:4.3340, val_acc:0.0788
# Epoch 78/100 : train_loss:4.3258, train_acc:0.0777, val_loss:4.3315, val_acc:0.0789
# Epoch 79/100 : train_loss:4.3234, train_acc:0.0782, val_loss:4.3291, val_acc:0.0795
# Epoch 80/100 : train_loss:4.3209, train_acc:0.0786, val_loss:4.3267, val_acc:0.0798
# Epoch 81/100 : train_loss:4.3184, train_acc:0.0786, val_loss:4.3243, val_acc:0.0799
# Epoch 82/100 : train_loss:4.3159, train_acc:0.0789, val_loss:4.3220, val_acc:0.0803
# Epoch 83/100 : train_loss:4.3134, train_acc:0.0798, val_loss:4.3196, val_acc:0.0808
# Epoch 84/100 : train_loss:4.3109, train_acc:0.0801, val_loss:4.3173, val_acc:0.0806
# Epoch 85/100 : train_loss:4.3085, train_acc:0.0803, val_loss:4.3150, val_acc:0.0807
# Epoch 86/100 : train_loss:4.3060, train_acc:0.0805, val_loss:4.3127, val_acc:0.0820
# Epoch 87/100 : train_loss:4.3039, train_acc:0.0808, val_loss:4.3104, val_acc:0.0826
# Epoch 88/100 : train_loss:4.3013, train_acc:0.0811, val_loss:4.3081, val_acc:0.0827
# Epoch 89/100 : train_loss:4.2991, train_acc:0.0813, val_loss:4.3059, val_acc:0.0830
# Epoch 90/100 : train_loss:4.2968, train_acc:0.0817, val_loss:4.3037, val_acc:0.0834
# Epoch 91/100 : train_loss:4.2945, train_acc:0.0821, val_loss:4.3014, val_acc:0.0831
# Epoch 92/100 : train_loss:4.2921, train_acc:0.0827, val_loss:4.2993, val_acc:0.0839
# Epoch 93/100 : train_loss:4.2897, train_acc:0.0828, val_loss:4.2971, val_acc:0.0839
# Epoch 94/100 : train_loss:4.2875, train_acc:0.0833, val_loss:4.2949, val_acc:0.0845
# Epoch 95/100 : train_loss:4.2851, train_acc:0.0835, val_loss:4.2928, val_acc:0.0848
# Epoch 96/100 : train_loss:4.2830, train_acc:0.0838, val_loss:4.2907, val_acc:0.0848
# Epoch 97/100 : train_loss:4.2808, train_acc:0.0840, val_loss:4.2886, val_acc:0.0849
# Epoch 98/100 : train_loss:4.2786, train_acc:0.0842, val_loss:4.2865, val_acc:0.0851
# Epoch 99/100 : train_loss:4.2764, train_acc:0.0847, val_loss:4.2845, val_acc:0.0853

# %%
import pandas as pd
pd.DataFrame(histroy).plot()

# %%
jovian.commit()
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Please enter your API key ( from https://jovian.ai/ ):
# API KEY: ··········
# [jovian] Uploading colab notebook to Jovian...
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ai/developer-jnk/cifar100-pytorch-classification
# 'https://jovian.ai/developer-jnk/cifar100-pytorch-classification'
